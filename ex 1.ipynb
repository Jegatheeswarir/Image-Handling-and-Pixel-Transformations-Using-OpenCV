# %%
import cv2
img = cv2.imread('Eagle_in_Flight.jpg', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# # Name: Jegatheeswari R
# Reg No: 212223230092

# %%
image = cv2.imread('Eagle_in_Flight.jpg')
print("Height, Width and Channel:", image.shape)
# Out:
# Height, Width and Channel: (600, 768, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
cv2.imwrite('Eagle_in_Flight.png', image)
# Out:
# True

# %%
img = cv2.imread('Eagle_in_Flight.png')
color_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(color_img)

# %%
plt.imshow(color_img)
color_img.shape
# Out:
# (600, 768, 3)

# %%
cropped = color_img[10:450, 150:570]
plt.imshow(cropped)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(419.5), np.float64(439.5), np.float64(-0.5))

# %%
height, width = image.shape[:2]
resized_image = cv2.resize(image, (width * 2, height * 2), interpolation=cv2.INTER_LINEAR)
plt.imshow(resized_image)

# %%
flipped = cv2.flip(resized_image, 1)
plt.imshow(flipped)

# %%
img_apollo = cv2.imread('Apollo-11-launch.jpg')

# %%
cv2.putText(img_apollo, 'Apollo 11 Saturn V Launch, July 16, 1969', (50, img_apollo.shape[0] - 50), cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 2)
plt.imshow(img_apollo)

# %%
cv2.rectangle(img_apollo, (400, 30), (750, 600), (255, 0, 255), 3)
# Out:
# array([[[213, 213, 213],
#         [213, 213, 213],
#         [210, 210, 210],
#         ...,
#         [241, 241, 241],
#         [240, 240, 240],
#         [241, 241, 241]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [239, 239, 239],
#         [240, 240, 240]],
#
#        [[213, 213, 213],
#         [212, 212, 212],
#         [209, 209, 209],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        ...,
#
#        [[ 47,  47,  47],
#         [ 46,  46,  46],
#         [ 42,  42,  42],
#         ...,
#         [ 17,  17,  17],
#         [ 11,  11,  11],
#         [  5,   5,   5]],
#
#        [[ 44,  44,  44],
#         [ 47,  47,  47],
#         [ 47,  47,  47],
#         ...,
#         [ 17,  17,  17],
#         [ 10,  10,  10],
#         [  4,   4,   4]],
#
#        [[ 43,  43,  43],
#         [ 49,  49,  49],
#         [ 52,  52,  52],
#         ...,
#         [ 13,  13,  13],
#         [  9,   9,   9],
#         [  4,   4,   4]]], shape=(720, 1280, 3), dtype=uint8)

# %%
plt.imshow(img_apollo)

# %%
boy_img = cv2.imread('Boy.jpg')

# %%
import numpy as np
matrix_ones = np.ones(boy_img.shape, dtype='uint8') * 50

# %%
img_brighter = cv2.add(img, matrix)
img_darker = cv2.subtract(img, matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 img_brighter = cv2.add(img, matrix)
#       2 img_darker = cv2.subtract(img, matrix)
#
# NameError: name 'matrix' is not defined
